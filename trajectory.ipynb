# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("20191210130806-1324367673.csv", header=None)
df.head()
# Out:
#     0  1   2    3    4
# 0   1  1   5  1.0  5.0
# 1   1  2  10  1.0  5.0
# 2  10  2   5  0.0  5.0
# 3  10  3  10  0.0  5.0
# 4   1  3  15  1.0  5.0

# %%
df.columns = ["id", "step", "x", "y", "speed"]
df = df.loc[df['y'] == 1]
df = df.loc[df['step'] >= 3600]
df = df.loc[df['step'] < 4000]
df = df.loc[df['x'] >= 850]
df.head()
# Out:
#            id  step     x    y  speed
# 511753  34171  3600   907  1.0    0.0
# 511756  34251  3600   875  1.0    5.0
# 511767  34011  3600   933  1.0    5.0
# 511775  33970  3600   997  1.0    5.0
# 511776  33871  3600  1015  1.0    5.0

# %%
plt.scatter(df.step, df.x, c=df.speed)
plt.show()

# %%
plt.figure(figsize=(24,12), dpi=600)
plt.scatter(df.step, df.x, c=df.speed, marker=",", s=1)
plt.show()

# %%
ax = sns.heatmap(df.pivot('x','step','speed'))

# %%
g = sns.lmplot("Detector.totalDensity", "Detector.totalFlow", data=barlovic, hue="Detector.idNum", markers=[".", "+", "x", "1"],
          fit_reg=False, legend=False)
#g.set(xlim=(0,50))
plt.legend(title="Detector", labels=['-1 km','-3 km', "-5 km", "-7 km"])
plt.xlabel("Density (1 / km)")
plt.ylabel("Flow (1 / h)")
plt.show(g)

# %%
with open('20191207165616-1324367673.json') as json_file:
    data = json.load(json_file)
ai = pd.io.json.json_normalize(data)

# %%
g = sns.lmplot("Detector.totalDensity", "Detector.totalFlow", data=ai, hue="Detector.idNum", markers=[".", "+", "x", "1"],
          fit_reg=False, legend=False)
#g.set(xlim=(0,50))
plt.legend(title="Detector", labels=['-1 km','-3 km', "-5 km", "-7 km"])
plt.xlabel("Density (1 / km)")
plt.ylabel("Flow (1 / h)")
plt.show(g)

# %%
with open('20191206182008-1324367673.json') as json_file:
    data = json.load(json_file)
ai2 = pd.io.json.json_normalize(data)

# %%
g = sns.lmplot("Detector.totalDensity", "Detector.totalFlow", data=ai2, hue="Detector.idNum", markers=[".", "+", "x", "1"],
          fit_reg=False, legend=False)
#g.set(xlim=(0,50))
plt.legend(title="Detector", labels=['-1 km','-3 km', "-5 km", "-7 km"])
plt.xlabel("Density (1 / km)")
plt.ylabel("Flow (1 / h)")
plt.show(g)

# %%
with open('20191206182817-1324367673.json') as json_file:
    data = json.load(json_file)
ai2 = pd.io.json.json_normalize(data)

# %%
g = sns.lmplot("Detector.totalDensity", "Detector.totalFlow", data=ai2, hue="Detector.idNum", markers=[".", "+", "x", "1"],
          fit_reg=False, legend=False)
#g.set(xlim=(0,50))
plt.legend(title="Detector", labels=['-1 km','-3 km', "-5 km", "-7 km"])
plt.xlabel("Density (1 / km)")
plt.ylabel("Flow (1 / h)")
plt.show(g)
